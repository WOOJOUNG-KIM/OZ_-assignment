# %% [markdown]
# <a href="https://colab.research.google.com/github/WOOJOUNG-KIM/OZ_-assignment/blob/main/level1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 안녕하세요.<br><br>
# 수강생 여러분~!
#
# "Challenge : 사칙연산을 이용해 문제 풀기"는 잘 풀어보셨나요?
#
#
# 너~~무 어려웠어요! 하는 분들을 위해 만들어봤습니다!
#
# 문제 도장깨기 !!!!!
#
# 차근차근 풀어나가면 파이썬 정복 가능입니다!
#
# 화이팅 !
#
#
# Chapter04의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# <br>
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>
# <br>

# %% [markdown]
# -----

# %% [markdown]
# <br>
#
# __[문제1]__
#
# 한 상자에 사과가 7개 들어있습니다.
#
# 사과가 많이 먹고 싶어서 3개의 상자를 구입했습니다!
#
# 총 사과의 개수를 계산해주세요.
#
#
# <br>

# %%
#사과박스 사과 개수
apple = 7
apple_bax = 3

print(apple * apple_bax, "iteme")
# Out:
# 21 iteme

# %% [markdown]
# <br>
#
# __[문제2]__
#
# 영화 티켓 한 장의 가격은 10,000원입니다.
#
# 친구 한명이 로또에 당첨되서 티켓을 사준다고 합니다!
#
# 4명의 친구가 각각 4장씩 구매할 때, 총 가격이 어떻게 되는지 계산해주세요
#
# <br>

# %%
#영화티켓 한장 가격
movie_ticket = 10000

#총인원 총갯수
total_people = 4
total_ticket = 4

print(movie_ticket * total_people * total_ticket, "won")
# Out:
# 160000 won

# %% [markdown]
# <br>
#
# __[문제3]__
#
# 지각입니다 !!!!!
#
# 지하철을 타고 5개의 역이 남았습니다.
#
# 각 역은 3분씩 걸립니다. 시간을 계산해볼 수 있도록 5개의 역을 지나는데 걸린 총 시간을 구해주세요.

# %%
#남은 역 갯수
station = 5

#각 역 걸리는 시간
time = 3

print(station * time,"min")
# Out:
# 15 min

# %% [markdown]
# <br>__[문제4]__
#
# 파이썬 기초 관련 책이 9권 있습니다.
#
# 오즈코딩스쿨을 통해 파이썬을 마스터 해버려서 필요없습니다.
#
# 책을 3명의 친구에게 똑같이 나눠줄 때, 각 사람에게 몇 권씩 나누어줄 수 있을까요?

# %%
#남아 있는 책
book = 9

#친구 수
friend = 3

print(book // friend, "book")
# Out:
# 3 book

# %% [markdown]
# __[문제5]__
#
# 무인도에 2명의 갇혀있습니다.
#
# 가진건 초콜릿 8개뿐,,
#
# 각 사람은 초콜릿을 몇 개씩 먹을 수 있을까요?

# %%
#무인도 인원수
people = 2

#초콜릿 개수
cholocate = 8

print(cholocate // people, "cholocate")
# Out:
# 4 cholocate
